# %% [markdown]
# ## ALGORITMO LINEAL MULTIPLICATIVOS  - ESIS ( Nain Acero)

# %%
import numpy as np
import pandas  as pd
import os
import matplotlib.pyplot as plt

# %%
def lineal_multiplicativos(n, semilla, a, m, c):
    x = []
    for i in range(n):
        numero = ((a*semilla) + c) % m
        numero1 = numero/(m-1)
        x.append(numero1)
        semilla = numero
    return x

# %%
semilla = 6
a = 13
m = 8
c = 7
data = lineal_multiplicativos(50, semilla, a, m, c)
print(data)
df = pd.DataFrame({'column':data}) 
df.to_csv('out_algoritmo_congruensales_multiplicativos.csv', index=False, header=['aleatorio'],sep=';',decimal='.')
df.to_csv('out_algoritmo_congruensales_multiplicativos.txt', index=False, header=['aleatorio'],sep=';',decimal='.')
# Out:
# [0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0, 1.0, 0.2857142857142857, 0.14285714285714285, 0.5714285714285714, 0.42857142857142855, 0.8571428571428571, 0.7142857142857143, 0.0]

# %%
plt.plot(data)

# %%
plt.hist(data)
# Out:
# (array([ 5.,  5.,  5.,  5.,  5.,  5.,  5.,  0.,  5., 10.]),
#  array([0.03125, 0.125  , 0.21875, 0.3125 , 0.40625, 0.5    , 0.59375,
#         0.6875 , 0.78125, 0.875  , 0.96875]),
#  <BarContainer object of 10 artists>)
