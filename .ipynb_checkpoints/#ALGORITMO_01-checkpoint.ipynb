# %% [markdown]
# ## ALGORITMO CUADRADOS MEDIOS - ESIS ( Nain Acero)

# %%
import numpy as np
import pandas  as pd
import os
import matplotlib.pyplot as plt

# %%
def cuadrados_medios(n, semilla):
    x = []
    tam1 = len(semilla)
    numero1 = int(semilla)
    for i in range(n):
        numero2 = pow(numero1, 2)
        snumero2 = str(numero2)
        tam2 = len(snumero2)
        primerc = (tam2 - tam1) / 2
        snumero3 = snumero2[int(primerc):int(primerc+tam1)]
        x.append(float(str(0) + '.' +  snumero3))
        numero1 = int(snumero3)
    return x

# %%
semilla = "7543"
data = cuadrados_medios(50, semilla)
print(data)
df = pd.DataFrame({'column':data}) 
df.to_csv('out.csv', index=False, header=False,sep=';',decimal=',')
# Out:
# [0.8968, 0.425, 0.0625, 0.9062, 0.1198, 0.4352, 0.9399, 0.3412, 0.6417, 0.1778, 0.1612, 0.5985, 0.8202, 0.2728, 0.4419, 0.5275, 0.8256, 0.1615, 0.6082, 0.9907, 0.1486, 0.2081, 0.3305, 0.923, 0.1929, 0.721, 0.9841, 0.8452, 0.4363, 0.0357, 0.2744, 0.5295, 0.037, 0.369, 0.6161, 0.9579, 0.7572, 0.3351, 0.2292, 0.2532, 0.411, 0.8921, 0.5842, 0.1289, 0.6615, 0.7582, 0.4867, 0.6876, 0.2793, 0.8008]

# %%
plt.plot(data)

# %%
plt.hist(data)
# Out:
# (array([5., 6., 5., 5., 5., 5., 4., 3., 5., 7.]),
#  array([0.0357, 0.1312, 0.2267, 0.3222, 0.4177, 0.5132, 0.6087, 0.7042,
#         0.7997, 0.8952, 0.9907]),
#  <BarContainer object of 10 artists>)
