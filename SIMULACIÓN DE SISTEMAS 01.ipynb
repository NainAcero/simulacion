# %% [markdown]
# ### SIMULACIÓN DE SISTEMAS - ESIS (NAIN)

# %%
import numpy as np
import pandas  as pd
import os
import matplotlib.pyplot as plt

# %%
def randint_list(n):
    x = []
    for i in range(n):
      x.append(np.random.random())
    return x

# %%
datos = randint_list(200)
print(datos)
dato_ln = []
for dato in datos:
    ln = np.log(1-dato)
    dato_ln.append(-3*ln)
# Out:
# [0.04585331848414387, 0.4989000322649495, 0.40274443528202286, 0.5901000107243942, 0.3512040465845906, 0.9469294703542153, 0.8398030442794276, 0.5639815466810537, 0.45692465271672333, 0.5121000480692367, 0.375734602403918, 0.35152027077529524, 0.9653757939988169, 0.621700767088553, 0.8610328732903099, 0.6412126530433807, 0.8355459221890419, 0.7809204446010299, 0.10649654834669209, 0.6648200909034204, 0.4617188305787059, 0.9869821662861281, 0.8052930495295816, 0.6143535658521426, 0.5204772474783803, 0.7957893026913953, 0.8466460676584144, 0.29241288771154983, 0.7400798886449602, 0.00398421403687943, 0.014443407624975313, 0.8214965657533145, 0.15611800769517126, 0.8115327662253841, 0.969961883560957, 0.3315468538443834, 0.4025900269353472, 0.002325323170560778, 0.7254090592569732, 0.15254928436102266, 0.12642317050420837, 0.7290780145478039, 0.5690060017934422, 0.17618748527906736, 0.6561275570282328, 0.2784659324807348, 0.5541177856271957, 0.0731491879177546, 0.5619421547283149, 0.771
# ...

# %%
plt.plot(datos, dato_ln, 'ro')

# %%
plt.plot(dato_ln)

# %%
data = [
    0.6435, 0.9849, 0.9152, 0.8327, 0.2803, 0.1730, 0.9002, 0.1853, 0.3499, 0.7368,
    0.0168, 0.1133, 0.5673, 0.5013, 0.0330, 0.9814, 0.7602, 0.1865, 0.5518, 0.1064,
    0.3553, 0.3846, 0.3063, 0.1319, 0.3769, 0.3809, 0.5290, 0.8586, 0.6225, 0.5425,
    0.1242, 0.2806, 0.9285, 0.4257, 0.5007, 0.9997, 0.2072, 0.0580, 0.5460, 0.3910,
    0.4006, 0.2376, 0.3883, 0.7998, 0.9111, 0.5554, 0.6080, 0.6724, 0.0332, 0.9451,
    0.2944, 0.5657, 0.4072, 0.6198, 0.6809, 0.7154, 0.8810, 0.3028, 0.5950, 0.3131,
    0.1438, 0.7546, 0.0982, 0.4946, 0.1837, 0.5438, 0.6598, 0.6460, 0.8039, 0.1599,
    0.7612, 0.8071, 0.5163, 0.5810, 0.6720, 0.6020, 0.0120, 0.4502, 0.4228, 0.2734,
    0.4776, 0.1012, 0.0935, 0.4389, 0.7195, 0.7738, 0.8939, 0.5225, 0.1220, 0.8265,
    0.6031, 0.9288, 0.1209, 0.5537, 0.1219, 0.9657, 0.9734, 0.9955, 0.2281, 0.1084,

]

# %%
data_x = []
con = 0
sum = 0
for x in data:
    con = con + 1
    sum = sum + x
    data_x.append(sum / con)

# %%
plt.plot(data_x)

# %%
np.random.seed(2020)
for i in range(5):
    print( np.random.random() )
# Out:
# 0.9862768288615988
# 0.8733919458206546
# 0.5097455249715815
# 0.27183571428207576
# 0.33691872774596354

# %%
a = 1
b = 100 
n = 20
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([4., 2., 1., 1., 2., 3., 1., 1., 2., 3.]),
#  array([ 5.09286461, 14.42672549, 23.76058637, 33.09444725, 42.42830813,
#         51.76216901, 61.09602989, 70.42989077, 79.76375165, 89.09761253,
#         98.43147341]),
#  <BarContainer object of 10 artists>)
