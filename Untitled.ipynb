    0.7612, 0.8071, 0.5163, 0.5810, 0.6720, 0.6020, 0.0120, 0.4502, 0.4228, 0.2734,
    0.4776, 0.1012, 0.0935, 0.4389, 0.7195, 0.7738, 0.8939, 0.5225, 0.1220, 0.8265,
    0.6031, 0.9288, 0.1209, 0.5537, 0.1219, 0.9657, 0.9734, 0.9955, 0.2281, 0.1084,

]

# %%
data_x = []
con = 0
sum = 0
for x in data:
    con = con + 1
    sum = sum + x
    data_x.append(sum / con)

# %%
plt.plot(data_x)

# %%
np.random.seed(2020)
for i in range(5):
    print( np.random.random() )
# Out:
# 0.9862768288615988
# 0.8733919458206546
# 0.5097455249715815
# 0.27183571428207576
# 0.33691872774596354

# %%
a = 1
b = 100 
n = 20
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([4., 2., 1., 1., 2., 3., 1., 1., 2., 3.]),
#  array([ 5.09286461, 14.42672549, 23.76058637, 33.09444725, 42.42830813,
#         51.76216901, 61.09602989, 70.42989077, 79.76375165, 89.09761253,
#         98.43147341]),
#  <BarContainer object of 10 artists>)

# %%
semilla = "5735"
tam1 = len(semilla)
numero1 = int(semilla)
for i in range(10):
    numero2 = pow(numero1, 2)
    snumero2 = str(numero2)
    tam2 = len(snumero2)
    primerc = (tam2 - tam1) / 2
    number = primerc+tam1
    snumero3 = snumero2[int(primerc):int(number)]
    print(0,",",snumero3)
    numero1 = int(snumero3)
# Out:
# 0 , 8902
# 0 , 2456
# 0 , 0319
# 0 , 0176
# 0 , 3097
# 0 , 5914
# 0 , 9753
# 0 , 1210
# 0 , 4641
# 0 , 5388

# %%
semilla = "5015"
semilla2 = "5734"
tam1 = len(semilla) + len(semilla2)
numero1 = int(semilla) * int(semilla2)
for i in range(10):
    numero2 = pow(numero1, 2)
    snumero2 = str(numero2)
    tam2 = len(snumero2)
    primerc = (tam2 - tam1) / 2
    number = primerc+tam1
    snumero3 = snumero2[int(primerc):int(number)]
    print(0,",",snumero3)
    numero1 = int(snumero3)
# Out:
# 0 , 90811112
# 0 , 65806267
# 0 , 46477647
# 0 , 17167065
# 0 , 70812071
# 0 , 34939930
# 0 , 79870840
# 0 , 35108230
# 0 , 58781373
# 0 , 24981176

# %%
semilla = "6965"
constante = "9803"
tam1 = len(semilla)
numero1 = int(semilla) * int(semilla2)
for i in range(10):
    numero2 = pow(numero1, 2)
    snumero2 = str(numero2)
    tam2 = len(snumero2)
    primerc = (tam2 - tam1) / 2
    number = primerc+tam1
    snumero3 = snumero2[int(primerc):int(number)]
    print(0,",",snumero3)
    numero1 = int(snumero3)
